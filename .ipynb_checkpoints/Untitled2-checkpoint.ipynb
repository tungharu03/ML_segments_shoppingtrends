# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
from IPython.display import Image
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv(r'datafake\10000.csv')
df1.sample(5)
# Out:
#       Gender  Age  Category  Item Purchased  Size  Color  Season  Location  \
# 496        1   30         1               5     1     10       2         2
# 7982       2   53         3              24     4     23       3        46
# 4575       2   55         3              20     4     22       3        31
# 3083       2   22         1               3     1     16       4         4
# 6949       2   52         3              24     4     24       3        44
#
#       Subscription Status  Payment Method  Shipping Type  \
# 496                     2               5              5
# 7982                    2               6              5
# 4575                    1               5              5
# 3083                    1               5              3
# 6949                    2               6              6
#
#       Preferred Payment Method  Previous Purchases  Review Rating  \
# 496                          5                  31              3
# 7982                         4                  34              4
# 4575                         5                  37              4
# 3083                         1                  28              3
# 6949                         5                  35              4
#
#       Frequency of Purchases
# 496                        6
# 7982                       5
# 4575                       6
# 3083                       3
# 6949                       5

# %%
df2 = pd.read_csv(r'datafake\20000.csv')

# %%
df3 = pd.read_csv(r'datafake\30000.csv')

# %%
df4 = pd.read_csv(r'datafake\40000.csv')

# %%
df5 = pd.read_csv(r'datafake\50000.csv')

# %%
df6 = pd.read_csv(r'datafake\60000.csv')

# %%
df7 = pd.read_csv(r'datafake\70000.csv')

# %%
df8 = pd.read_csv(r'datafake\80000.csv')

# %%
df9 = pd.read_csv(r'datafake\90000.csv')

# %%
df10 = pd.read_csv(r'datafake\100000.csv')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Assume combined_df is already available as per previous context

# Lấy features và labels từ DataFrame
X = df1.drop('Frequency of Purchases', axis=1)
y = df1['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Độ chính xác của mô hình sau khi tối ưu: 0.499

# %%
# Lấy features và labels từ DataFrame
X = df2.drop('Frequency of Purchases', axis=1)
y = df2['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Độ chính xác của mô hình sau khi tối ưu: 0.6713333333333333

# %%
# Lấy features và labels từ DataFrame
X = df3.drop('Frequency of Purchases', axis=1)
y = df3['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Độ chính xác của mô hình sau khi tối ưu: 0.48633333333333334

# %%
# Lấy features và labels từ DataFrame
X = df4.drop('Frequency of Purchases', axis=1)
y = df4['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)

# %%
# Assume combined_df is already available as per previous context

# Lấy features và labels từ DataFrame
X = df5.drop('Frequency of Purchases', axis=1)
y = df5['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)

grid_search.fit(X_train, y_train)
s
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Độ chính xác của mô hình sau khi tối ưu: 0.41186666666666666
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Độ chính xác của mô hình sau khi tối ưu: 0.41186666666666666

# %%
# Lấy features và labels từ DataFrame
X = df6.drop('Frequency of Purchases', axis=1)
y = df6['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Độ chính xác của mô hình sau khi tối ưu: 0.7612777777777778

# %%
# Lấy features và labels từ DataFrame
X = df7.drop('Frequency of Purchases', axis=1)
y = df7['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Độ chính xác của mô hình sau khi tối ưu: 0.4561904761904762

# %%
# Lấy features và labels từ DataFrame
X = df8.drop('Frequency of Purchases', axis=1)
y = df8['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Độ chính xác của mô hình sau khi tối ưu: 0.637625

# %%
# Lấy features và labels từ DataFrame
X = df9.drop('Frequency of Purchases', axis=1)
y = df9['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Độ chính xác của mô hình sau khi tối ưu: 0.7328518518518519

# %%
# Lấy features và labels từ DataFrame
X = df10.drop('Frequency of Purchases', axis=1)
y = df10['Frequency of Purchases']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)

# Định nghĩa Random Forest Classifier
clf = RandomForestClassifier(random_state=17)

# Định nghĩa các tham số cần tối ưu với ít lựa chọn hơn
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tốt nhất với ít kết hợp hơn và ít số lần gấp
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Huấn luyện mô hình
grid_search.fit(X_train, y_train)

# In ra các tham số tốt nhất
print("Best Parameters:", grid_search.best_params_)

# Dự đoán nhãn của tập kiểm tra sử dụng mô hình tốt nhất
best_clf = grid_search.best_estimator_
y_pred = best_clf.predict(X_test)

# Tính độ chính xác của mô hình
accuracy = accuracy_score(y_test, y_pred)
print("Độ chính xác của mô hình sau khi tối ưu:", accuracy)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Độ chính xác của mô hình sau khi tối ưu: 0.7066333333333333
